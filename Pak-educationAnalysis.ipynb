# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('./Dataset/educationdata.csv')
data.dropna(inplace=True)
data.isnull().sum()
data
# Out:
#     % Boys Enrolled  % Complete Primary Schools % Girls Enrolled  \
# 0            54.77%                    0.936599           45.23%
# 1            62.50%                    0.594203           37.50%
# 3            60.77%                    0.827225           39.23%
# 4            60.75%                    0.592348           39.25%
# 5            58.48%                    0.582192           41.52%
# 6            68.36%                    0.940718           31.64%
# 8            62.60%                    0.846975           37.40%
# 9            57.87%                    0.707042           42.13%
# 10          100.00%                    0.239631            0.00%
# 11           88.21%                    0.000000           11.79%
# 12           80.41%                    0.342723           19.59%
# 13          100.00%                    0.612245            0.00%
# 14           82.59%                    0.244240           17.41%
# ...

# %%
year= data.groupby('Province')

# %%
balocistan = year.get_group('Balochistan')
ajk        = year.get_group('AJK')
fata       = year.get_group('FATA')
gb         = year.get_group('GB')
ict        = year.get_group('ICT')
kp         = year.get_group('KP')
punjab     = year.get_group('Punjab')
sindh      = year.get_group('Sindh')

balocistan_year = balocistan.groupby('Year')
ajk_year        = ajk.groupby('Year')
fata_year       = fata.groupby('Year')
gb_year         = gb.groupby('Year')
ict_year        = ict.groupby('Year')
kp_year         = kp.groupby('Year')
punjab_year     = punjab.groupby('Year')
sindh_year      = sindh.groupby('Year')

# %%
balocistan_year2013 = balocistan_year.get_group(2013)
balocistan_year2014 = balocistan_year.get_group(2014)
balocistan_year2015 = balocistan_year.get_group(2015)
balocistan_year2016 = balocistan_year.get_group(2016)
ajk_year2013        = ajk_year.get_group(2013)
ajk_year2014        = ajk_year.get_group(2014)
ajk_year2015        = ajk_year.get_group(2015)
ajk_year2016        = ajk_year.get_group(2016)
fata_year2013       = fata_year.get_group(2013)
fata_year2014       = fata_year.get_group(2014)
fata_year2015       = fata_year.get_group(2015)
fata_year2016       = fata_year.get_group(2016)
gb_year2013         = gb_year.get_group(2013)
gb_year2014         = gb_year.get_group(2014)
gb_year2015         = gb_year.get_group(2015)
gb_year2016         = gb_year.get_group(2016)
ict_year2013        = ict_year.get_group(2013)
ict_year2014        = ict_year.get_group(2014)
ict_year2015        = ict_year.get_group(2015)
ict_year2016        = ict_year.get_group(2016)
kp_year2013         = kp_year.get_group(2013)
kp_year2014         = kp_year.get_group(2014)
kp_year2015         = kp_year.get_group(2015)
kp_year2016         = kp_year.get_group(2016)
punjab_year2013     = punjab_year.get_group(2013)
punjab_year2014     = punjab_year.get_group(2014)
punjab_year2015     = punjab_year.get_group(2015)
punjab_year2016     = punjab_year.get_group(2016)
sindh_year2013      = sindh_year.get_group(2013)
sindh_year2014      = sindh_year.get_group(2014)
sindh_year2015      = sindh_year.get_group(2015)
sindh_year2016      = sindh_year.get_group(2016)

# %% [markdown]
# # Getting Boys Enrolled Data

# %%
bb2013     = balocistan_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
bb2014     = balocistan_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
bb2015     = balocistan_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
bb2016     = balocistan_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

ab2013            = ajk_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ab2014            = ajk_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ab2015            = ajk_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ab2016            = ajk_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

fb2013           = fata_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
fb2014           = fata_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
fb2015           = fata_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
fb2016           = fata_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

gb2013             = gb_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
gb2014             = gb_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
gb2015             = gb_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
gb2016             = gb_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

ib2013            = ict_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ib2014            = ict_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ib2015            = ict_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
i2016            = ict_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

kb2013             = kp_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
k2014             = kp_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
kb2015             = kp_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
kb2016             = kp_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

pb2013         = punjab_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
pb2014         = punjab_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
pb2015         = punjab_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
pb2016         = punjab_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

sb2013          = sindh_year2013['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
sb2014          = sindh_year2014['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
sb2015          = sindh_year2015['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
sb2016          = sindh_year2016['% Boys Enrolled'].apply(lambda x :float(x.replace('%',''))/100)


bb2013         =bb2013.sum()
bb2014         =bb2014.sum()
bb2015         =bb2015.sum()
bb2016         =bb2016.sum() 

ab2013        =ab2013.sum()
ab2014        =ab2014.sum()
ab2015        =ab2015.sum()
ab2016        =ab2016.sum()

fb2013       =fb2013.sum()
fb2014       =fb2014.sum()
fb2015       =fb2015.sum()
fb2016       =fb2016.sum()

gb2013         =gb2013.sum()
gb2014         =gb2014.sum()
gb2015         =gb2015.sum()
gb2016         =gb2016.sum()

ib2013        =ib2013.sum()
ib2014        =ib2014.sum()
ib2015        =ib2015.sum()
ib2016        =ib2016.sum()

kb2013         =kb2013.sum()
kb2014         =kb2014.sum()
kb2015         =kb2015.sum()
kb2016         =kb2016.sum()

pb2013     =pb2013.sum()
pb2014     =pb2014.sum()
pb2015     =pb2015.sum()
pb2016     =pb2016.sum()

sb2013      =sb2013.sum()
sb2014      =sb2014.sum()
sb2015      =sb2015.sum()
sb2016      =sb2016.sum()

# %%
prov_name = data["Province"].unique()
prov = prov_name.tolist()

# %% [markdown]
# # Plotting Boys Enrolled Data

# %%
year = ["2103","2014","2015","2016"]
AJK=[ab2013,ab2014,ab2015,ab2016]
Balochistan = [bb2013,bb2014,bb2015,bb2016]
FATA = [fb2013,fb2014,fb2015,fb2016]
GB = [gb2013,gb2014,gb2015,gb2016]
ICT = [ib2013,ib2014,ib2015,ib2016]
KP = [kb2013,kb2014,kb2015,kb2016]
Punjab = [pb2013,pb2014,pb2015,pb2016]
Sindh = [sb2013,sb2014,sb2015,sb2016]
fig, ax = plt.subplots(4, 2)
fig.suptitle('Percentage of Boys Enrolled in all Province',fontsize=16,x=0.5, y=0.9, horizontalalignment='left', verticalalignment='top')
ax[0,0].plot(year,AJK,marker='o', markerfacecolor='#FC766AFF', markersize=12, color='#5B84B1FF', linewidth=4)
ax[0,1].plot(year,Balochistan,marker='o', markerfacecolor='#5F4B8BFF', markersize=12, color='#5B84B1FF', linewidth=4)
ax[1,0].plot(year,FATA,marker='o', markerfacecolor='#42EADDFF', markersize=12, color='#CDB599FF', linewidth=4)
ax[1,1].plot(year,GB,marker='o', markerfacecolor='#00A4CCFF', markersize=12, color='#F95700FF', linewidth=4)
ax[2,0].plot(year,ICT,marker='o', markerfacecolor='#00203FFF', markersize=12, color='#ADEFD1FF', linewidth=4)
ax[2,1].plot(year,KP,marker='o', markerfacecolor='#606060FF', markersize=12, color='#D6ED17FF', linewidth=4)
ax[3,0].plot(year,Punjab,marker='o', markerfacecolor='#ED2B33FF', markersize=12, color='#D85A7FFF', linewidth=4)
ax[3,1].plot(year,Sindh,marker='o', markerfacecolor='#2C5F2D', markersize=12, color='#97BC62FF', linewidth=4)
fig.legend(prov,loc='upper center')
fig.subplots_adjust(left=0, bottom=1, right=2, top=4, wspace=0.5, hspace=0.5)
fig.show()

# %% [markdown]
# # Getting Girls Enrolled Data1

# %%
bg2013     = balocistan_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
bg2014     = balocistan_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
bg2015     = balocistan_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
bg2016     = balocistan_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

ag2013            = ajk_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ag2014            = ajk_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ag2015            = ajk_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ag2016            = ajk_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

fg2013           = fata_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
fg2014           = fata_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
fg2015           = fata_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
fg2016           = fata_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

gg2013             = gb_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
gg2014             = gb_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
gg2015             = gb_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
gg2016             = gb_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

ig2013            = ict_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ig2014            = ict_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ig2015            = ict_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
ig2016            = ict_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

kg2013             = kp_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
kg2014             = kp_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
kg2015             = kp_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
kg2016             = kp_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

pg2013         = punjab_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
pg2014         = punjab_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
pg2015         = punjab_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
pg2016         = punjab_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)

sg2013          = sindh_year2013['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
sg2014          = sindh_year2014['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
sg2015          = sindh_year2015['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)
sg2016          = sindh_year2016['% Girls Enrolled'].apply(lambda x :float(x.replace('%',''))/100)


bg2013        =bg2013.sum()
bg2014        =bg2014.sum()
bg2015        =bg2015.sum()
bg2016        =bg2016.sum() 

ag2013        =ag2013.sum()
ag2014        =ag2014.sum()
ag2015        =ag2015.sum()
ag2016        =ag2016.sum()

fg2013       =fg2013.sum()
fg2014       =fg2014.sum()
fg2015       =fg2015.sum()
fg2016       =fg2016.sum()

gg2013         =gg2013.sum()
gg2014         =gg2014.sum()
gg2015         =gg2015.sum()
gg2016         =gg2016.sum()

ig2013        =ig2013.sum()
ig2014        =ig2014.sum()
ig2015        =ig2015.sum()
ig2016        =ig2016.sum()

kg2013         =kg2013.sum()
kg2014         =kg2014.sum()
kg2015         =kg2015.sum()
kg2016         =kg2016.sum()

pg2013         =pg2013.sum()
pg2014        =pg2014.sum()
pg2015        =pg2015.sum()
pg2016        =pg2016.sum()

sg2013         =sg2013.sum()
sg2014        =sg2014.sum()
sg2015        =sg2015.sum()
sg2016        =sg2016.sum()

# %% [markdown]
# # Plotting Girls Enrolled Data

# %%
year = ["2103","2014","2015","2016"]
AJK=[ag2013,ag2014,ag2015,ag2016]
Balochistan = [bg2013,bg2014,bg2015,bg2016]
FATA = [fg2013,fg2014,fg2015,fg2016]
GB = [gg2013,gg2014,gg2015,gg2016]
ICT = [ig2013,ig2014,ig2015,ig2016]
KP = [kg2013,kg2014,kg2015,kg2016]
Punjab = [pg2013,pg2014,pg2015,pg2016]
Sindh = [sg2013,sg2014,sg2015,sg2016]
fig, ax = plt.subplots(4, 2)
fig.suptitle('Percentage of Girls Enrolled in all Province',fontsize=16,x=0.5, y=0.9, horizontalalignment='left', verticalalignment='top')
ax[0,0].plot(year,AJK,marker='o', markerfacecolor='#FC766AFF', markersize=12, color='#5B84B1FF', linewidth=4)
ax[0,1].plot(year,Balochistan,marker='o', markerfacecolor='#5F4B8BFF', markersize=12, color='#5B84B1FF', linewidth=4)
ax[1,0].plot(year,FATA,marker='o', markerfacecolor='#42EADDFF', markersize=12, color='#CDB599FF', linewidth=4)
ax[1,1].plot(year,GB,marker='o', markerfacecolor='#00A4CCFF', markersize=12, color='#F95700FF', linewidth=4)
ax[2,0].plot(year,ICT,marker='o', markerfacecolor='#00203FFF', markersize=12, color='#ADEFD1FF', linewidth=4)
ax[2,1].plot(year,KP,marker='o', markerfacecolor='#606060FF', markersize=12, color='#D6ED17FF', linewidth=4)
ax[3,0].plot(year,Punjab,marker='o', markerfacecolor='#ED2B33FF', markersize=12, color='#D85A7FFF', linewidth=4)
ax[3,1].plot(year,Sindh,marker='o', markerfacecolor='#2C5F2D', markersize=12, color='#97BC62FF', linewidth=4)
fig.legend(prov,loc='upper center')
fig.subplots_adjust(left=0, bottom=1, right=2, top=4, wspace=0.5, hspace=0.5)
fig.show()

# %% [markdown]
# # Plotting AJK Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
AJK_girls=[ag2013,ag2014,ag2015,ag2016]
AJK_boys=[ab2013,ab2014,ab2015,ab2016]
plt.plot(year,AJK_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,AJK_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("AJK Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting GB Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
GB_girls=[gg2013,gg2014,gg2015,gg2016]
GB_boys=[gb2013,gb2014,gb2015,gb2016]
plt.plot(year,GB_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,GB_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("GB Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting FATA Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
FATA_girls=[fg2013,fg2014,fg2015,fg2016]
FATA_boys=[fb2013,fb2014,fb2015,fb2016]
plt.plot(year,FATA_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,FATA_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("FATA Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting ICT Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
ICT_girls=[ig2013,ig2014,ig2015,ig2016]
ICT_boys=[ib2013,ib2014,ib2015,ib2016]
plt.plot(year,ICT_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,ICT_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("ICT Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting Balochistan Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
BALOCH_girls=[bg2013,bg2014,bg2015,bg2016]
BALOCH_boys=[bb2013,bb2014,bb2015,bb2016]
plt.plot(year,BALOCH_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,BALOCH_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("BALOCHISTAN Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting KPK Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
KPK_girls=[kg2013,kg2014,kg2015,kg2016]
KPK_boys=[kb2013,kb2014,kb2015,kb2016]
plt.plot(year,KPK_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,KPK_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("KPK Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting PUNJAB Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
PUNJ_girls=[pg2013,pg2014,pg2015,pg2016]
PUNJ_boys=[pb2013,pb2014,pb2015,pb2016]
plt.plot(year,PUNJ_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,PUNJ_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("KPK Boys and Girls Enrolled % Ratio")
plt.show()

# %% [markdown]
# # Plotting SINDH Boys and Girls Enrolled Data

# %%
gender=["Boys","Girls"]
year = ["2103","2014","2015","2016"]
SINDH_girls=[sg2013,sg2014,sg2015,sg2016]
SINDH_boys=[sb2013,sb2014,sb2015,sb2016]
plt.plot(year,SINDH_boys,marker='o', markerfacecolor='#53adcb', markersize=12, color='#153944', linewidth=4)
plt.plot(year,SINDH_girls,marker='o', markerfacecolor='#ff8da1', markersize=12, color='#ff0f39', linewidth=4)
plt.legend(gender,loc='upper right')
plt.title("KPK Boys and Girls Enrolled % Ratio")
plt.show()
